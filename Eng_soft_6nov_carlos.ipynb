# %% [markdown]
# <a href="https://colab.research.google.com/github/carlosfelix08/tecnicas-de-programacao-UDF/blob/main/Eng_soft_6nov_carlos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Operadores

# %%
2**3
# Out:
# 8

# %%
23/7
# Out:
# 3.2857142857142856

# %%
23//7
# Out:
# 3

# %%
23%7
# Out:
# 2

# %%
5+5*5/5
# Out:
# 10.0

# %%
4 ** (4 / 2) + 7
# Out:
# 23.0

# %%
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
print(f"A soma dos dois números corresponde a {n1 + n2}")
# Out:
# Digite o primeiro número: 5
# Digite o segundo número: 4
# A soma dos dois números corresponde a 9

# %% [markdown]
# #Exercícios

# %%
'''
1- Faça um programa que leia dois números
inteiros e exiba a soma deles.
'''
n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))
print(f"A soma dos dois números corresponde a {n1 + n2}")
# Out:
# Digite o primeiro número: 2
# Digite o segundo número: 3
# A soma dos dois números corresponde a 5

# %%
'''
2- Faça um programa que leia a nota que um aluno tirou em P1(Prova 1) e P2(Prova 2).
Calcule a média aritmética. Exiba esse resultado na tela.
'''
P1 = float(input("Digite a nota da prova 1: "))
P2 = float(input("Digite a nota da prova 2: "))
media = (P1 + P2) / 2
print(f"A média do aluno é {media}")
# Out:
# Digite a nota da prova 1: 3
# Digite a nota da prova 2: 5
# A média do aluno é 4.0

# %%
'''
3- Leia um nome armazenado em uma variável e imprima:
Olá, nome_pessoa! (nome_pessoa é a variável)
'''
nome = str(input("Digite seu nome: "))
print(f"Olá, {nome}!")
# Out:
# Digite seu nome: Carlos
# Olá, Carlos!

# %%
'''
4- Solicite que o usuário digite seu nome.
Solicite que o usuários digite seu ano de nascimento (formato AAAA).
Exiba na tela: nome_usuario nasceu em ano_nascimento!
(nome_usuario e ano_nascimento são as variáveis)
'''
nome = str(input("Digite seu nome: "))
ano_nascimento = int(input("Digite seu ano de nascimento: "))
print(f"{nome} nasceu em {ano_nascimento}!")
# Out:
# Digite seu nome: Carlos
# Digite seu ano de nascimento: 2006
# Carlos nasceu em 2006!

# %%
'''
5- Solicite que o usuário digite seu nome e sua idade.
Imprima “Olá, nome! Você tem idade anos?”
Imprima o ano de nascimento da pessoa (ignore meses e dias)
Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)
'''
nome = str(input("Digite seu nome: "))
idade = int(input("Digite sua idade: "))
print(f"Olá, {nome}! Você tem {idade} anos?")
print(f"{nome} nasceu em {2025 - idade}!")
print((nome) * idade)
# Out:
# Digite seu nome: Carlos
# Digite sua idade: 19
# Olá, Carlos! Você tem 19 anos?
# Carlos nasceu em 2006!
# CarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlosCarlos

# %%
'''
6- Solicite ao usuário que digite três notas
depois calcule e exiba a média ponderada.
'''
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
media = (n1 * 2 + n2 * 3 + n3 * 5) / 10
print(f"A média ponderada é {media}")
# Out:
# Digite a primeira nota: 5
# Digite a segunda nota: 5
# Digite a terceira nota: 5
# A média ponderada é 5.0

# %%
'''
7- Solicite ao usuário três notas e seus
respectivos pesos, depois calcule e exiba a
média ponderada.
'''
n1 = float(input("Digite a primeira nota: "))
n2 = float(input("Digite a segunda nota: "))
n3 = float(input("Digite a terceira nota: "))
peso1 = float(input("Digite o peso da primeira nota: "))
peso2 = float(input("Digite o peso da segunda nota: "))
peso3 = float(input("Digite o peso da terceira nota: "))
media = (n1 * peso1 + n2 * peso2 + n3 * peso3) / (peso1 + peso2 + peso3)
print(f"A média ponderada é {media}")
# Out:
# Digite a primeira nota: 3
# Digite a segunda nota: 2
# Digite a terceira nota: 5
# Digite o peso da primeira nota: 1
# Digite o peso da segunda nota: 1
# Digite o peso da terceira nota: 3
# A média ponderada é 4.0

# %%
'''
8- Peça ao usuário um número e exiba a soma
de seus dígitos.
'''
numero = int(input("Digite um número: "))
soma = 0
while numero > 0:
    digito = numero % 10
    soma += digito
    numero //= 10
print(f"A soma dos dígitos é {soma}")
# Out:
# Digite um número: 53
# A soma dos dígitos é 8

# %%
'''
9- Peça ao usuário uma palavra e exiba-a
invertida sem usar laços.
'''
palavra = str(input("Digite uma palavra: "))
print(palavra[::-1])
# Out:
# Digite uma palavra: oi
# io
